# %%
# %cd ..
# Out:
# /workspaces/nInChI_prototype

# %%
# !python -m pytest --testset=mol tests/test_canonicalization.py::test_permutation
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.9.10, pytest-7.0.1, pluggy-1.0.0
# rootdir: /workspaces/nInChI_prototype
# plugins: anyio-3.5.0
# collected 183 items
#
# tests/test_canonicalization.py ......................................... [ 22%]
# ........................................................................ [ 61%]
# ......................................................................   [100%]
#
# ============================= 183 passed in 7.56s ==============================

# %%
# !python -m pytest -v --durations=5 --testset=mol tests/test_canonicalization.py::test_invariance
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.9.10, pytest-7.0.1, pluggy-1.0.0 -- /opt/conda/bin/python
# cachedir: .pytest_cache
# rootdir: /workspaces/nInChI_prototype
# plugins: anyio-3.5.0
# collected 183 items
#
# tests/test_canonicalization.py::test_invariance[10tertButyl10isopropyltridecanoic acid] PASSED [  0%]
# tests/test_canonicalization.py::test_invariance[14Ethyl14methylheptadecanoic acid] PASSED [  1%]
# tests/test_canonicalization.py::test_invariance[18Methylnonadecanoic acid] PASSED [  1%]
# tests/test_canonicalization.py::test_invariance[2 4 Dimethylbutan] PASSED [  2%]
# tests/test_canonicalization.py::test_invariance[2 Chlortoluol] PASSED    [  2%]
# tests/test_canonicalization.py::test_invariance[2-8-dimethyldecane] PASSED [  3%]
# tests/test_canonicalization.py::test_invariance[2-aminopyridine] PASSED  [  3%]
# ...

# %%
# !python -m pytest -v --durations=5 --testset=mol tests/test_canonicalization.py::test_invariance --only-connected-graphs
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.9.10, pytest-7.0.1, pluggy-1.0.0 -- /opt/conda/bin/python
# cachedir: .pytest_cache
# rootdir: /workspaces/nInChI_prototype
# plugins: anyio-3.5.0
# collected 156 items
#
# tests/test_canonicalization.py::test_invariance[10tertButyl10isopropyltridecanoic acid] PASSED [  0%]
# tests/test_canonicalization.py::test_invariance[14Ethyl14methylheptadecanoic acid] PASSED [  1%]
# tests/test_canonicalization.py::test_invariance[18Methylnonadecanoic acid] PASSED [  1%]
# tests/test_canonicalization.py::test_invariance[2 4 Dimethylbutan] PASSED [  2%]
# tests/test_canonicalization.py::test_invariance[2 Chlortoluol] PASSED    [  3%]
# tests/test_canonicalization.py::test_invariance[2-8-dimethyldecane] PASSED [  3%]
# tests/test_canonicalization.py::test_invariance[2-aminopyridine] PASSED  [  4%]
# ...

# %%
# !python -m pytest --durations=5 --testset=mol tests/test_canonicalization.py::test_bijection --only-connected-graphs
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.9.10, pytest-7.0.1, pluggy-1.0.0
# rootdir: /workspaces/nInChI_prototype
# plugins: anyio-3.5.0
# collected 1 item
#
# tests/test_canonicalization.py F                                         [100%]
#
# =================================== FAILURES ===================================
# ________________________________ test_bijection ________________________________
#
#     def test_bijection():
#         """Eineindeutigkeit."""
#         serializations = set()
#         for f in pytest.testset:
#             m = graph_from_file(f)
#             m_serialized = serialize_molecule(canonicalize_molecule(m, 0))
# >           assert m_serialized not in serializations, f"duplicate: {f.stem}"
# E           AssertionError: duplicate: TCNE_SGROUP
# ...

# %%
# !python -m pytest --testset=cfi tests/test_canonicalization.py::test_permutation
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.9.10, pytest-7.0.1, pluggy-1.0.0
# rootdir: /workspaces/nInChI_prototype
# plugins: anyio-3.5.0
# collected 322 items
#
# tests/test_canonicalization.py ......................................... [ 12%]
# ........................................................................ [ 35%]
# ........................................................................ [ 57%]
# ........................................................................ [ 79%]
# .................................................................        [100%]
#
# ======================= 322 passed in 123.24s (0:02:03) ========================

# %%
# !python -m pytest -v --durations=5 --testset=cfi tests/test_canonicalization.py::test_invariance
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.9.10, pytest-7.0.1, pluggy-1.0.0 -- /opt/conda/bin/python
# cachedir: .pytest_cache
# rootdir: /workspaces/nInChI_prototype
# plugins: anyio-3.5.0
# collected 322 items
#
# tests/test_canonicalization.py::test_invariance[cfi-rigid-d3-0180-01-1] PASSED [  0%]
# tests/test_canonicalization.py::test_invariance[cfi-rigid-d3-0180-02-1] PASSED [  0%]
# tests/test_canonicalization.py::test_invariance[cfi-rigid-d3-0180-03-1] PASSED [  0%]
# tests/test_canonicalization.py::test_invariance[cfi-rigid-d3-0180-04-1] PASSED [  1%]
# tests/test_canonicalization.py::test_invariance[cfi-rigid-d3-0360-01-1] PASSED [  1%]
# tests/test_canonicalization.py::test_invariance[cfi-rigid-d3-0360-02-1] PASSED [  1%]
# tests/test_canonicalization.py::test_invariance[cfi-rigid-d3-0360-03-1] PASSED [  2%]
# tests/test_canonicalization.py::test_invariance[cfi-rigid-d3-0360-04-1] PASSED [  2%]
# ...

# %%
# !python -m pytest --durations=5 --testset=cfi tests/test_canonicalization.py::test_bijection
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.9.10, pytest-7.0.1, pluggy-1.0.0
# rootdir: /workspaces/nInChI_prototype
# plugins: anyio-3.5.0
# collected 1 item
#
# tests/test_canonicalization.py .                                         [100%]
#
# ============================= slowest 5 durations ==============================
# 190.39s call     tests/test_canonicalization.py::test_bijection
#
# (2 durations < 0.005s hidden.  Use -vv to show these durations.)
# ======================== 1 passed in 190.66s (0:03:10) =========================
