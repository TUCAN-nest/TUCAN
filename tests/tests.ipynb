# %%
# %cd ..
# Out:
# /workspaces/nInChI_prototype

# %%
# !python -m pytest --testset=mol tests/test_canonicalization.py::test_permutation
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.9.7, pytest-7.0.1, pluggy-1.0.0
# rootdir: /workspaces/nInChI_prototype
# plugins: anyio-3.5.0
# collected 165 items
#
# tests/test_canonicalization.py ......................................... [ 24%]
# ........................................................................ [ 68%]
# ....................................................                     [100%]
#
# ============================= 165 passed in 7.47s ==============================

# %%
# !python -m pytest -v --durations=1 --testset=mol tests/test_canonicalization.py::test_invariance
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.9.7, pytest-7.0.1, pluggy-1.0.0 -- /opt/conda/bin/python
# cachedir: .pytest_cache
# rootdir: /workspaces/nInChI_prototype
# plugins: anyio-3.5.0
# collected 165 items
#
# tests/test_canonicalization.py::test_invariance[10tertButyl10isopropyltridecanoic acid] PASSED [  0%]
# tests/test_canonicalization.py::test_invariance[14Ethyl14methylheptadecanoic acid] PASSED [  1%]
# tests/test_canonicalization.py::test_invariance[18Methylnonadecanoic acid] PASSED [  1%]
# tests/test_canonicalization.py::test_invariance[2 4 Dimethylbutan] PASSED [  2%]
# tests/test_canonicalization.py::test_invariance[2 Chlortoluol] PASSED    [  3%]
# tests/test_canonicalization.py::test_invariance[2-8-dimethyldecane] PASSED [  3%]
# tests/test_canonicalization.py::test_invariance[2-aminopyridine] PASSED  [  4%]
# tests/test_canonicalization.py::test_invariance[3 Chlortoluol] PASSED    [  4%]
# ...

# %%
# !python -m pytest -v --durations=1 --testset=mol tests/test_canonicalization.py::test_invariance --only-connected-graphs
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.9.7, pytest-7.0.1, pluggy-1.0.0 -- /opt/conda/bin/python
# cachedir: .pytest_cache
# rootdir: /workspaces/nInChI_prototype
# plugins: anyio-3.5.0
# collected 140 items
#
# tests/test_canonicalization.py::test_invariance[10tertButyl10isopropyltridecanoic acid] PASSED [  0%]
# tests/test_canonicalization.py::test_invariance[14Ethyl14methylheptadecanoic acid] PASSED [  1%]
# tests/test_canonicalization.py::test_invariance[18Methylnonadecanoic acid] PASSED [  2%]
# tests/test_canonicalization.py::test_invariance[2 4 Dimethylbutan] PASSED [  2%]
# tests/test_canonicalization.py::test_invariance[2 Chlortoluol] PASSED    [  3%]
# tests/test_canonicalization.py::test_invariance[2-8-dimethyldecane] PASSED [  4%]
# tests/test_canonicalization.py::test_invariance[2-aminopyridine] PASSED  [  5%]
# tests/test_canonicalization.py::test_invariance[3 Chlortoluol] PASSED    [  5%]
# ...

# %%
# !python -m pytest --durations=1 --testset=mol tests/test_canonicalization.py::test_bijection --only-connected-graphs
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.9.7, pytest-7.0.1, pluggy-1.0.0
# rootdir: /workspaces/nInChI_prototype
# plugins: anyio-3.5.0
# collected 1 item
#
# tests/test_canonicalization.py .                                         [100%]
#
# ============================= slowest 1 durations ==============================
# 2.58s call     tests/test_canonicalization.py::test_bijection
# ============================== 1 passed in 2.72s ===============================

# %%
# !python -m pytest --testset=cfi tests/test_canonicalization.py::test_permutation
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.9.7, pytest-7.0.1, pluggy-1.0.0
# rootdir: /workspaces/nInChI_prototype
# plugins: anyio-3.5.0
# collected 322 items
#
# tests/test_canonicalization.py ......................................... [ 12%]
# ........................................................................ [ 35%]
# ........................................................................ [ 57%]
# ........................................................................ [ 79%]
# .................................................................        [100%]
#
# ======================= 322 passed in 121.54s (0:02:01) ========================

# %%
# !python -m pytest -v --durations=1 --testset=cfi tests/test_canonicalization.py::test_invariance
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.9.7, pytest-7.0.1, pluggy-1.0.0 -- /opt/conda/bin/python
# cachedir: .pytest_cache
# rootdir: /workspaces/nInChI_prototype
# plugins: anyio-3.5.0
# collected 322 items
#
# tests/test_canonicalization.py::test_invariance[cfi-rigid-d3-0180-01-1] PASSED [  0%]
# tests/test_canonicalization.py::test_invariance[cfi-rigid-d3-0180-02-1] PASSED [  0%]
# tests/test_canonicalization.py::test_invariance[cfi-rigid-d3-0180-03-1] PASSED [  0%]
# tests/test_canonicalization.py::test_invariance[cfi-rigid-d3-0180-04-1] PASSED [  1%]
# tests/test_canonicalization.py::test_invariance[cfi-rigid-d3-0360-01-1] PASSED [  1%]
# tests/test_canonicalization.py::test_invariance[cfi-rigid-d3-0360-02-1] PASSED [  1%]
# tests/test_canonicalization.py::test_invariance[cfi-rigid-d3-0360-03-1] PASSED [  2%]
# tests/test_canonicalization.py::test_invariance[cfi-rigid-d3-0360-04-1] PASSED [  2%]
# ...

# %%
# !python -m pytest --durations=1 --testset=cfi tests/test_canonicalization.py::test_bijection
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.9.7, pytest-7.0.1, pluggy-1.0.0
# rootdir: /workspaces/nInChI_prototype
# plugins: anyio-3.5.0
# collected 1 item
#
# tests/test_canonicalization.py .                                         [100%]
#
# ============================= slowest 1 durations ==============================
# 154.33s call     tests/test_canonicalization.py::test_bijection
# ======================== 1 passed in 154.54s (0:02:34) =========================
