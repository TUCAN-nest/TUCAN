# %%
# %cd ..

# %%
from chembl_webresource_client.new_client import new_client
from tucan.canonicalization import _graph_from_moldata
from tucan.visualization import draw_molecules
from tests.test_canonicalization import test_invariance
from networkx.algorithms.components import is_connected
from time import ctime


def _parse_molfile2000(molfile: str):
    lines = [[l[i:i + 3].strip(" ") for i in range(0, len(l), 3)] for l in molfile.splitlines()]
    atom_count = int(lines[3][0])
    bond_count = int(lines[3][1])
    atom_block_offset = 4
    bond_block_offset = atom_block_offset + atom_count
    element_symbols = [
        l[10] for l in lines[atom_block_offset : atom_block_offset + atom_count]
    ]
    assert (
        len(element_symbols) == atom_count
    ), f"Number of atoms {len(element_symbols)} doesn't match atom-count specified in header {atom_count}."
    bonds = [
        (int(l[0]) - 1, int(l[1]) - 1)
        for l in lines[bond_block_offset : bond_block_offset + bond_count]
    ]  # make bond-indices zero-based
    assert (
        len(bonds) == bond_count
    ), f"Number of bonds {len(bonds)} doesn't match bond-count specified in header {bond_count}."
    return element_symbols, bonds


def graph_from_molfile2000(molfile: str):
    element_symbols, bonds = _parse_molfile2000(molfile)
    return _graph_from_moldata(element_symbols, bonds)

# %%
client = new_client.molecule
molecules = client.only(['molecule_chembl_id', 'molecule_structures'])

n_tested = 0
for m in molecules:
    chembl_id = m["molecule_chembl_id"]
    try:
        molfile = m["molecule_structures"]["molfile"]
        graph = graph_from_molfile2000(molfile)
    except Exception as e:    # for some structures data isn't available
        print(f"{chembl_id}: {e}")
        continue
    if not is_connected(graph):    # only test connected graphs for now
        continue
    
    
    try:
        test_invariance(graph)
    except AssertionError as e:
        print(f"Invariance test failed with {chembl_id}: {e}")
        draw_molecules([graph], [m["molecule_chembl_id"]])
    n_tested += 1
    if not n_tested % 1000:
        print(f"{ctime()}: tested {n_tested} molecules.")
# Out:
# CHEMBL373625: 'NoneType' object is not subscriptable
# CHEMBL387335: 'NoneType' object is not subscriptable
# CHEMBL267704: 'NoneType' object is not subscriptable
# CHEMBL6614: 'NoneType' object is not subscriptable
# CHEMBL6688: 'NoneType' object is not subscriptable
# CHEMBL6763: 'NoneType' object is not subscriptable
# CHEMBL269099: 'NoneType' object is not subscriptable
# CHEMBL7042: 'NoneType' object is not subscriptable
# CHEMBL6757: 'NoneType' object is not subscriptable
# CHEMBL6739: 'NoneType' object is not subscriptable
# CHEMBL441330: 'NoneType' object is not subscriptable
# CHEMBL266471: 'NoneType' object is not subscriptable
# CHEMBL6811: 'NoneType' object is not subscriptable
# CHEMBL269100: 'NoneType' object is not subscriptable
# CHEMBL266733: 'NoneType' object is not subscriptable
# CHEMBL6513: 'NoneType' object is not subscriptable
# CHEMBL7006: 'NoneType' object is not subscriptable
# CHEMBL415294: 'NoneType' object is not subscriptable
# ...
