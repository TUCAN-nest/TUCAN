# %%
# %cd ..
# Out:
# /workspaces/nInChI_prototype

# %%
# !python -m pytest --testset=mol tests/test_canonicalization.py::test_permutation
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.9.7, pytest-7.0.1, pluggy-1.0.0
# rootdir: /workspaces/nInChI_prototype
# plugins: anyio-3.5.0
# collected 113 items
#
# tests/test_canonicalization.py ......................................... [ 36%]
# ........................................................................ [100%]
#
# ============================= 113 passed in 9.06s ==============================

# %%
# !python -m pytest -vv --durations=0 --testset=mol tests/test_canonicalization.py::test_invariance
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.9.7, pytest-7.0.1, pluggy-1.0.0 -- /opt/conda/bin/python
# cachedir: .pytest_cache
# rootdir: /workspaces/nInChI_prototype
# plugins: anyio-3.5.0
# collected 113 items
#
# tests/test_canonicalization.py::test_invariance[10tertButyl10isopropyltridecanoic acid] PASSED [  0%]
# tests/test_canonicalization.py::test_invariance[14Ethyl14methylheptadecanoic acid] PASSED [  1%]
# tests/test_canonicalization.py::test_invariance[18Methylnonadecanoic acid] PASSED [  2%]
# tests/test_canonicalization.py::test_invariance[2 4 Dimethylbutan] PASSED [  3%]
# tests/test_canonicalization.py::test_invariance[2 Chlortoluol] PASSED    [  4%]
# tests/test_canonicalization.py::test_invariance[2-8-dimethyldecane] PASSED [  5%]
# tests/test_canonicalization.py::test_invariance[2-aminopyridine] PASSED  [  6%]
# tests/test_canonicalization.py::test_invariance[3 Chlortoluol] PASSED    [  7%]
# ...

# %%
# !python -m pytest --durations=0 --testset=mol tests/test_canonicalization.py::test_bijection
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.9.7, pytest-7.0.1, pluggy-1.0.0
# rootdir: /workspaces/nInChI_prototype
# plugins: anyio-3.5.0
# collected 1 item
#
# tests/test_canonicalization.py .                                         [100%]
#
# ============================== slowest durations ===============================
# 3.75s call     tests/test_canonicalization.py::test_bijection
#
# (2 durations < 0.005s hidden.  Use -vv to show these durations.)
# ============================== 1 passed in 9.19s ===============================

# %%
# !python -m pytest --testset=cfi tests/test_canonicalization.py::test_permutation
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.9.7, pytest-7.0.1, pluggy-1.0.0
# rootdir: /workspaces/nInChI_prototype
# plugins: anyio-3.5.0
# collected 322 items
#
# tests/test_canonicalization.py ......................................... [ 12%]
# ........................................................................ [ 35%]
# ........................................................................ [ 57%]
# ........................................................................ [ 79%]
# .................................................................        [100%]
#
# ======================= 322 passed in 217.50s (0:03:37) ========================

# %%
# !python -m pytest -vv --durations=0 --testset=cfi tests/test_canonicalization.py::test_invariance
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.9.7, pytest-7.0.1, pluggy-1.0.0 -- /opt/conda/bin/python
# cachedir: .pytest_cache
# rootdir: /workspaces/nInChI_prototype
# plugins: anyio-3.5.0
# collected 322 items
#
# tests/test_canonicalization.py::test_invariance[cfi-rigid-d3-0180-01-1] PASSED [  0%]
# tests/test_canonicalization.py::test_invariance[cfi-rigid-d3-0180-02-1] PASSED [  0%]
# tests/test_canonicalization.py::test_invariance[cfi-rigid-d3-0180-03-1] PASSED [  0%]
# tests/test_canonicalization.py::test_invariance[cfi-rigid-d3-0180-04-1] PASSED [  1%]
# tests/test_canonicalization.py::test_invariance[cfi-rigid-d3-0360-01-1] PASSED [  1%]
# tests/test_canonicalization.py::test_invariance[cfi-rigid-d3-0360-02-1] PASSED [  1%]
# tests/test_canonicalization.py::test_invariance[cfi-rigid-d3-0360-03-1] PASSED [  2%]
# tests/test_canonicalization.py::test_invariance[cfi-rigid-d3-0360-04-1] PASSED [  2%]
# ...

# %%
# !python -m pytest --durations=0 --testset=cfi tests/test_canonicalization.py::test_bijection
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.9.7, pytest-7.0.1, pluggy-1.0.0
# rootdir: /workspaces/nInChI_prototype
# plugins: anyio-3.5.0
# collected 1 item
#
# tests/test_canonicalization.py .                                         [100%]
#
# ============================== slowest durations ===============================
# 254.14s call     tests/test_canonicalization.py::test_bijection
#
# (2 durations < 0.005s hidden.  Use -vv to show these durations.)
# ======================== 1 passed in 257.06s (0:04:17) =========================
