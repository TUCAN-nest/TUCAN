# %%
# %cd ..
# Out:
# /workspaces/tucan

# %%
# !pytest tests/test_canonicalization.py::test_regression -vv
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.9.10, pytest-7.1.1, pluggy-1.0.0 -- /usr/local/bin/python3
# cachedir: .pytest_cache
# rootdir: /workspaces/tucan
# collected 3 items
#
# tests/test_canonicalization.py::test_regression[ferrocene-C10H10Fe/1-11/2-12/3-13/4-14/5-15/6-16/7-17/8-18/9-19/10-20/11-12/11-13/11-21/12-14/12-21/13-15/13-21/14-15/14-21/15-21/16-17/16-20/16-21/17-18/17-21/18-19/18-21/19-20/19-21/20-21] PASSED [ 33%]
# tests/test_canonicalization.py::test_regression[bipyridine-C10H8N2/1-9/2-10/3-11/4-12/5-13/6-14/7-15/8-16/9-11/9-13/10-12/10-14/11-15/12-16/13-17/14-18/15-19/16-20/17-18/17-19/18-20] PASSED [ 66%]
# tests/test_canonicalization.py::test_regression[cf3alkyne-C6H5F3O2/1-6/2-6/3-6/4-9/5-9/6-9/7-8/7-10/8-11/9-13/10-12/10-13/11-14/11-15/11-16] PASSED [100%]
#
# ============================== 3 passed in 0.43s ===============================

# %%
# !pytest --testset=mol tests/test_canonicalization.py::test_permutation
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.9.10, pytest-7.1.1, pluggy-1.0.0
# rootdir: /workspaces/tucan
# collected 197 items
#
# tests/test_canonicalization.py ......................................... [ 20%]
# ........................................................................ [ 57%]
# ...ss.s..............................ss................................. [ 93%]
# ............                                                             [100%]
#
# ======================= 192 passed, 5 skipped in 11.56s ========================

# %%
# !pytest -v --durations=5 --testset=mol tests/test_canonicalization.py::test_invariance
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.9.10, pytest-7.1.1, pluggy-1.0.0 -- /usr/local/bin/python3
# cachedir: .pytest_cache
# rootdir: /workspaces/tucan
# collected 197 items
#
# tests/test_canonicalization.py::test_invariance[10tertButyl10isopropyltridecanoic acid] PASSED [  0%]
# tests/test_canonicalization.py::test_invariance[14Ethyl14methylheptadecanoic acid] PASSED [  1%]
# tests/test_canonicalization.py::test_invariance[18Methylnonadecanoic acid] PASSED [  1%]
# tests/test_canonicalization.py::test_invariance[1_2_dimethylnaphthalene] PASSED [  2%]
# tests/test_canonicalization.py::test_invariance[1_3_dimethylnaphthalene] PASSED [  2%]
# tests/test_canonicalization.py::test_invariance[1_3_diphenylpropane] PASSED [  3%]
# tests/test_canonicalization.py::test_invariance[1_3_methyl_phenyl_3_phenylpropane] PASSED [  3%]
# tests/test_canonicalization.py::test_invariance[1_4_dimethylnaphthalene] PASSED [  4%]
# ...

# %%
# !pytest -v --durations=5 --testset=mol tests/test_canonicalization.py::test_invariance --only-connected-graphs
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.9.10, pytest-7.1.1, pluggy-1.0.0 -- /usr/local/bin/python3
# cachedir: .pytest_cache
# rootdir: /workspaces/tucan
# collected 171 items
#
# tests/test_canonicalization.py::test_invariance[10tertButyl10isopropyltridecanoic acid] PASSED [  0%]
# tests/test_canonicalization.py::test_invariance[14Ethyl14methylheptadecanoic acid] PASSED [  1%]
# tests/test_canonicalization.py::test_invariance[18Methylnonadecanoic acid] PASSED [  1%]
# tests/test_canonicalization.py::test_invariance[1_2_dimethylnaphthalene] PASSED [  2%]
# tests/test_canonicalization.py::test_invariance[1_3_dimethylnaphthalene] PASSED [  2%]
# tests/test_canonicalization.py::test_invariance[1_3_diphenylpropane] PASSED [  3%]
# tests/test_canonicalization.py::test_invariance[1_3_methyl_phenyl_3_phenylpropane] PASSED [  4%]
# tests/test_canonicalization.py::test_invariance[1_4_dimethylnaphthalene] PASSED [  4%]
# ...

# %%
# !pytest --durations=5 --testset=mol tests/test_canonicalization.py::test_bijection
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.9.10, pytest-7.1.1, pluggy-1.0.0
# rootdir: /workspaces/tucan
# collected 1 item
#
# tests/test_canonicalization.py .                                         [100%]
#
# ============================= slowest 5 durations ==============================
# 4.52s call     tests/test_canonicalization.py::test_bijection
#
# (2 durations < 0.005s hidden.  Use -vv to show these durations.)
# ============================== 1 passed in 4.68s ===============================

# %%
# !pytest --testset=cfi tests/test_canonicalization.py::test_permutation
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.9.10, pytest-7.1.1, pluggy-1.0.0
# rootdir: /workspaces/tucan
# collected 322 items
#
# tests/test_canonicalization.py ......................................... [ 12%]
# ........................................................................ [ 35%]
# ........................................................................ [ 57%]
# ........................................................................ [ 79%]
# .................................................................        [100%]
#
# ============================= 322 passed in 46.16s =============================

# %%
# !pytest -v --durations=5 --testset=cfi tests/test_canonicalization.py::test_invariance
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.9.10, pytest-7.1.1, pluggy-1.0.0 -- /usr/local/bin/python3
# cachedir: .pytest_cache
# rootdir: /workspaces/tucan
# collected 322 items
#
# tests/test_canonicalization.py::test_invariance[cfi-rigid-d3-0180-01-1] FAILED [  0%]
# tests/test_canonicalization.py::test_invariance[cfi-rigid-d3-0180-02-1] FAILED [  0%]
# tests/test_canonicalization.py::test_invariance[cfi-rigid-d3-0180-03-1] FAILED [  0%]
# tests/test_canonicalization.py::test_invariance[cfi-rigid-d3-0180-04-1] FAILED [  1%]
# tests/test_canonicalization.py::test_invariance[cfi-rigid-d3-0360-01-1] FAILED [  1%]
# tests/test_canonicalization.py::test_invariance[cfi-rigid-d3-0360-02-1] FAILED [  1%]
# tests/test_canonicalization.py::test_invariance[cfi-rigid-d3-0360-03-1] FAILED [  2%]
# tests/test_canonicalization.py::test_invariance[cfi-rigid-d3-0360-04-1] FAILED [  2%]
# ...

# %%
# !pytest --durations=5 --testset=cfi tests/test_canonicalization.py::test_bijection
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.9.10, pytest-7.1.1, pluggy-1.0.0
# rootdir: /workspaces/tucan
# collected 1 item
#
# tests/test_canonicalization.py .                                         [100%]
#
# ============================= slowest 5 durations ==============================
# 139.61s call     tests/test_canonicalization.py::test_bijection
#
# (2 durations < 0.005s hidden.  Use -vv to show these durations.)
# ======================== 1 passed in 140.04s (0:02:20) =========================
